# %%
from premise import NewDatabase
import bw2data as bd

from config import Config
# Out:
# 2026-06-18T13:23:49.301883Z [warning  ] Brightway not installed; Brightway IO functionality disabled [wurst]

# %%
print(premise.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(premise.__version__)
#
# NameError: name 'premise' is not defined

# %%
config = Config()

# %%
bd.projects.set_current("Master thesis")

# %%
years = [2025, 2030, 2035, 2040, 2045, 2050]

scenarios = [{"model": "remind", "pathway": "SSP1-PkBudg650", "year": y} for y in years]

ndb = NewDatabase(
    scenarios=scenarios,
    source_db=config.SOURCE_DB,
    source_version=config.SOURCE_VERSION,
    key=config.KEY,
)
# Out:
# premise v.(2, 3, 9)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# ...

# %%
ndb.update()
# Out:
# Processing scenarios for all sectors: 100%|█| 6/6 [16:35<00:00, 165.91
# Done!

# %%
ndb.write_db_to_brightway(
    name=[
        "remind - SSP1-PkBudg650 - 2025",
        "remind - SSP1-PkBudg650 - 2030",
        "remind - SSP1-PkBudg650 - 2035",
        "remind - SSP1-PkBudg650 - 2040",
        "remind - SSP1-PkBudg650 - 2045",
        "remind - SSP1-PkBudg650 - 2050",
    ]
)
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# ...
# Title: Writing activities to SQLite3 database:
#   Started: 05/12/2026 22:49:29
#   Finished: 05/12/2026 22:49:59
#   Total time elapsed: 00:00:29
#   CPU %: 98.60
#   Memory %: 34.52
# Created database: remind - SSP1-PkBudg650 - 2025
# Running all checks...
# Minor anomalies found: check the change report.
# ...
# Title: Writing activities to SQLite3 database:
#   Started: 05/12/2026 22:52:33
#   Finished: 05/12/2026 22:53:06
#   Total time elapsed: 00:00:32
#   CPU %: 94.70
#   Memory %: 34.62
# Created database: remind - SSP1-PkBudg650 - 2030
# Running all checks...
# Minor anomalies found: check the change report.
# ...
# Title: Writing activities to SQLite3 database:
#   Started: 05/12/2026 22:55:53
#   Finished: 05/12/2026 22:56:26
#   Total time elapsed: 00:00:32
#   CPU %: 94.10
#   Memory %: 34.40
# Created database: remind - SSP1-PkBudg650 - 2035
# Running all checks...
# ...
